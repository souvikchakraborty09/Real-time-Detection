# %% [markdown]
# #Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !git config --global http.version HTTP/1.1

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
#Load Model

# %%
model= torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\91825/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-1-16 Python-3.10.5 torch-2.1.2+cu118 CUDA:0 (GeForce GTX 1650 Ti, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
#Make Detections

# %%
img='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0FiIgN85AzHqleBH8zoMxTkRhadsiI_J8Gg&usqp=CAU'

# %%
results=model(img)
results.print()
# Out:
# image 1/1: 183x275 22 cars, 5 trucks
# Speed: 375.6ms pre-process, 111.0ms inference, 16.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
#Real-time Detections

# %%
##Accessing the Webcam to do real-time detection
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    #Make Detections
    results=model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
##Train From Scratch
#To detect drowsiness

# %%
import uuid #Unique Identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake','drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.976cddf3-b456-11ee-8c62-5405dbea9d29.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.9f7e2921-b456-11ee-80a9-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2922-b456-11ee-83e2-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2923-b456-11ee-91c6-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2924-b456-11ee-8ac8-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2925-b456-11ee-86bd-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2926-b456-11ee-af6a-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2927-b456-11ee-b7f6-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2928-b456-11ee-84b3-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2929-b456-11ee-b935-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292a-b456-11ee-883d-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292b-b456-11ee-ae70-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292c-b456-11ee-a305-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292d-b456-11ee-9d03-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292e-b456-11ee-aa87-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e292f-b456-11ee-9213-5405dbea9d29.jpg
# ...
# data\images\awake.9f7e2930-b456-11ee-8a77-5405dbea9d29.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\91825\OneDrive\Desktop\Drowsiness': No such file or directory
# YOLOv5  2024-1-14 Python-3.10.5 torch-2.1.2+cu118 CUDA:0 (GeForce GTX 1650 Ti, 4096MiB)
#
# ...

# %%
##Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp4/weights/last.pt', force_reload=True) ##Change exp according to your last file inside runs folder
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\91825/.cache\torch\hub\master.zip
# YOLOv5  2024-1-16 Python-3.10.5 torch-2.1.2+cu118 CUDA:0 (GeForce GTX 1650 Ti, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.5e17e848-b456-11ee-8626-5405dbea9d29.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake, 1 drowsy
# Speed: 11.4ms pre-process, 23.0ms inference, 24.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
